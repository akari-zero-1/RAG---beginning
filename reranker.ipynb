# %%
from langchain_classic.retrievers import EnsembleRetriever
from langchain_community.retrievers import BM25Retriever
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain_cohere import CohereRerank
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# %pip install langchain-cohere
# Out:
# Requirement already satisfied: langchain-cohere in .\venv\Lib\site-packages (0.5.0)
# Requirement already satisfied: cohere<6.0,>=5.18.0 in .\venv\Lib\site-packages (from langchain-cohere) (5.20.7)
# Requirement already satisfied: langchain-community<0.5.0,>=0.4.0 in .\venv\Lib\site-packages (from langchain-cohere) (0.4.1)
# Requirement already satisfied: langchain-core<2.0,>=1.0.0 in .\venv\Lib\site-packages (from langchain-cohere) (1.2.16)
# Requirement already satisfied: pydantic<3,>=2 in .\venv\Lib\site-packages (from langchain-cohere) (2.12.5)
# Requirement already satisfied: types-pyyaml<7.0.0.0,>=6.0.12.20240917 in .\venv\Lib\site-packages (from langchain-cohere) (6.0.12.20250915)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in .\venv\Lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (1.12.1)
# Requirement already satisfied: httpx>=0.21.2 in .\venv\Lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (0.28.1)
# Requirement already satisfied: pydantic-core>=2.18.2 in .\venv\Lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (2.41.5)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in .\venv\Lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (2.32.5)
# Requirement already satisfied: tokenizers<1,>=0.15 in .\venv\Lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (0.22.2)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in .\venv\Lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (2.32.4.20260107)
# Requirement already satisfied: typing_extensions>=4.0.0 in .\venv\Lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (4.15.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in .\venv\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in .\venv\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (2.0.47)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in .\venv\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in .\venv\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\venv\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in .\venv\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in .\venv\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in .\venv\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.7.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in .\venv\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in .\venv\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (2.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in .\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in .\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\venv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in .\venv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in .\venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.1.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in .\venv\Lib\site-packages (from langchain-core<2.0,>=1.0.0->langchain-cohere) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in .\venv\Lib\site-packages (from langchain-core<2.0,>=1.0.0->langchain-cohere) (26.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in .\venv\Lib\site-packages (from langchain-core<2.0,>=1.0.0->langchain-cohere) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in .\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0,>=1.0.0->langchain-cohere) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in .\venv\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\venv\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in .\venv\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in .\venv\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.25.0)
# Requirement already satisfied: anyio in .\venv\Lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (4.12.1)
# Requirement already satisfied: certifi in .\venv\Lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\venv\Lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (1.0.9)
# Requirement already satisfied: idna in .\venv\Lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (3.11)
# Requirement already satisfied: h11>=0.16 in .\venv\Lib\site-packages (from httpcore==1.*->httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\venv\Lib\site-packages (from pydantic<3,>=2->langchain-cohere) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\venv\Lib\site-packages (from pydantic<3,>=2->langchain-cohere) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in .\venv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\venv\Lib\site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.18.0->langchain-cohere) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\venv\Lib\site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.18.0->langchain-cohere) (2.6.3)
# Requirement already satisfied: greenlet>=1 in .\venv\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.3.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in .\venv\Lib\site-packages (from tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (0.36.2)
# Requirement already satisfied: filelock in .\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in .\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (2026.2.0)
# Requirement already satisfied: tqdm>=4.42.1 in .\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (4.67.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\venv\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.1.0)
# Requirement already satisfied: colorama in .\venv\Lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# SETUP: Create expanded sample company data (50+ chunks)

# %%
chunks = [
    # Tesla - Financial & Production
    "Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.",
    "Tesla's automotive gross margin improved to 19.3% this quarter.",
    "Tesla Cybertruck production ramp begins in 2024 with initial deliveries.",
    "Tesla announced plans to expand Gigafactory production capacity.",
    "Tesla stock price reached new highs following earnings announcement.",
    "Tesla's energy storage business grew 40% year-over-year.",
    "Tesla continues to lead in electric vehicle market share globally.",
    "Tesla Model Y became the best-selling vehicle worldwide.",
    "Tesla reported strong free cash flow generation of $7.5 billion.",
    "Tesla's Full Self-Driving revenue increased significantly.",
    
    # Microsoft - Development & Acquisitions
    "Microsoft acquired GitHub for $7.5 billion in 2018.",
    "Microsoft's cloud revenue Azure grew 29% year-over-year.",
    "Microsoft announced new AI features for Visual Studio Code.",
    "Microsoft Teams integration with GitHub enhances developer workflow.",
    "Microsoft's developer tools division sees strong adoption.",
    "Microsoft acquired Activision Blizzard for $68.7 billion.",
    "Microsoft's productivity suite gained 50 million new users.",
    "Microsoft announced new Surface devices for developers.",
    "Microsoft's AI Copilot features expand to more development tools.",
    "Microsoft's enterprise solutions drive revenue growth.",
    
    # NVIDIA - AI & Hardware
    "NVIDIA's data center revenue reached $47.5 billion annually.",
    "NVIDIA's H100 GPUs see unprecedented demand for AI training.",
    "NVIDIA announced next-generation Blackwell architecture.",
    "NVIDIA's gaming revenue declined due to crypto market changes.",
    "NVIDIA's automotive AI platform partnerships expanded.",
    "NVIDIA's AI chip shortage affects cloud providers.",
    "NVIDIA stock valuation exceeds $2 trillion market cap.",
    "NVIDIA's CUDA platform dominates AI development.",
    "NVIDIA announced new AI inference chips for edge computing.",
    "NVIDIA's partnership with major cloud providers strengthens.",
    
    # Google/Alphabet - AI & Cloud
    "Google's AI investments total over $100 billion in recent years.",
    "Google Cloud revenue grew 35% reaching $8.4 billion quarterly.",
    "Google announced Gemini AI model competing with GPT-4.",
    "Google's search advertising revenue remains strong at $59 billion.",
    "Google's Workspace products integrate advanced AI features.",
    "Google announced quantum computing breakthroughs.",
    "Google's autonomous vehicle division Waymo expands operations.",
    "Google's AI research published breakthrough papers.",
    "Google's cloud AI services see enterprise adoption.",
    "Google faces regulatory scrutiny over AI dominance.",
    
    # Noisy/Less Relevant Chunks
    "The Tesla coil was invented by Nikola Tesla in 1891.",
    "Microsoft Excel spreadsheet formulas can be complex for beginners.",
    "NVIDIA Shield TV streaming device gets software update.",
    "Google Maps navigation improved with real-time traffic data.",
    "Production delays affected multiple manufacturing sectors.",
    "Financial markets showed volatility during earnings season.",
    "Revenue recognition standards changed for software companies.",
    "Hardware components face supply chain constraints globally.",
    "Development tools market grows with remote work trends.",
    "AI research requires significant computational resources.",
    "Quarterly reports show mixed results across tech sector.",
    "Stock market analysts upgrade technology sector ratings.",
    "Cloud computing adoption accelerates in enterprise market.",
    "Data center construction increases globally.",
    "Semiconductor shortage impacts various industries.",
    "Electric vehicle charging infrastructure expands rapidly.",
    "Software development productivity tools gain popularity.",
    "Machine learning frameworks become more accessible.",
    "Enterprise software licensing models evolve.",
    "Technology conferences showcase latest innovations."
]

print(f"Created {len(chunks)} sample chunks for demonstration")
# Out:
# Created 60 sample chunks for demonstration

# %%
# Convert to Document objects
documents = [Document(page_content=chunk, metadata={"source": f"chunk_{i}"}) for i, chunk in enumerate(chunks)]

# %% [markdown]
#
# SETUP: Create the three types of retrievers
#
# # 1. Vector Retriever (Semantic Search/Dense Retrieval)

# %% [markdown]
# Setting up hybrid retriever...

# %%
embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
vectorstore = Chroma.from_documents(
    documents=documents,
    embedding=embedding_model,
    collection_metadata={"hnsw:space": "cosine"}
)
vector_retriever = vectorstore.as_retriever(search_kwargs={"k": 15})

# %% [markdown]
# # 2. BM25 Retriever (Keyword Search/Sparse Retrieval)

# %%
# 2. BM25 Retriever
bm25_retriever = BM25Retriever.from_documents(documents)
bm25_retriever.k = 15

# %% [markdown]
# # 3. Hybrid Retriever

# %%
hybrid_retriever = EnsembleRetriever(
    retrievers=[vector_retriever, bm25_retriever],
    weights=[0.7, 0.3]
)

print("Setup complete!\n")
# Out:
# Setup complete!

# %% [markdown]
# Step 1: Get results from hybrid search (retrieve more chunks)

# %%
query = "Tesla financial performance and production updates"

print("STEP 1: Hybrid Search Results")
print("-"*50)

retrieved_docs = hybrid_retriever.invoke(query)  # Get top 25 for reranking

# Show top 10 from hybrid search
for i, doc in enumerate(retrieved_docs, 1):
    print(f"{i:2d}. {doc.page_content}")

print(f"\n(Retrieved {len(retrieved_docs)} total chunks for reranking)\n")
# Out:
# STEP 1: Hybrid Search Results
# --------------------------------------------------
#  1. Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.
#  2. Tesla reported strong free cash flow generation of $7.5 billion.
#  3. Tesla's automotive gross margin improved to 19.3% this quarter.
#  4. Tesla's energy storage business grew 40% year-over-year.
#  5. Tesla's Full Self-Driving revenue increased significantly.
#  6. Tesla announced plans to expand Gigafactory production capacity.
#  7. Tesla Cybertruck production ramp begins in 2024 with initial deliveries.
#  8. The Tesla coil was invented by Nikola Tesla in 1891.
#  9. Tesla Model Y became the best-selling vehicle worldwide.
# 10. Tesla stock price reached new highs following earnings announcement.
# 11. Tesla continues to lead in electric vehicle market share globally.
# 12. Electric vehicle charging infrastructure expands rapidly.
# 13. Technology conferences showcase latest innovations.
# 14. Machine learning frameworks become more accessible.
# 15. Enterprise software licensing models evolve.
# 16. Development tools market grows with remote work trends.
# 17. Hardware components face supply chain constraints globally.
# 18. Financial markets showed volatility during earnings season.
#
# (Retrieved 18 total chunks for reranking)

# %% [markdown]
# Step 2: Apply Cohere Reranking

# %%
import os

print("STEP 2: After Cohere Reranking (Top 10)")
print("-"*50)

cohere_api_key = os.getenv("CO_API_KEY")
rerank_applied = False

if cohere_api_key:
    try:
        # Initialize Cohere reranker
        reranker = CohereRerank(
            model="rerank-english-v3.0",
            top_n=10,
            cohere_api_key=cohere_api_key,
        )

        # Rerank the retrieved documents
        reranked_docs = reranker.compress_documents(retrieved_docs, query)
        rerank_applied = True
        print("✅ Cohere reranking applied")
    except Exception as e:
        print(f"⚠️ Cohere reranking failed: {e}")
        print("⚠️ Falling back to hybrid top-10 results")
        reranked_docs = retrieved_docs[:10]
else:
    print("⚠️ CO_API_KEY not found. Using hybrid top-10 as fallback.")
    reranked_docs = retrieved_docs[:10]

# Show reranked/fallback results
for i, doc in enumerate(reranked_docs, 1):
    print(f"{i:2d}. {doc.page_content}")

print("\n" + "="*80)
print("ANALYSIS:")
print("✅ Hybrid Search: Mixed relevant and irrelevant results")
if rerank_applied:
    print("✅ Reranking: Most relevant Tesla financial/production info moved to top")
else:
    print("⚠️ Reranking skipped (missing/invalid CO_API_KEY), showing hybrid fallback")
print("✅ Notice how top results prioritize query-relevant chunks")

# Optional: Show the difference more clearly
print("\n" + "="*80)
print("KEY VIEW (TOP RESULTS):")
print("-"*40)

hybrid_top_5 = [doc.page_content for doc in retrieved_docs[:5]]
reranked_top_5 = [doc.page_content for doc in reranked_docs[:5]]

print("BEFORE (Hybrid Top 5):")
for i, content in enumerate(hybrid_top_5, 1):
    print(f"  {i}. {content}")

print("\nAFTER (Step 2 Top 5):")
for i, content in enumerate(reranked_top_5, 1):
    print(f"  {i}. {content}")
# Out:
# STEP 2: After Cohere Reranking (Top 10)
# --------------------------------------------------
# ⚠️ CO_API_KEY not found. Using hybrid top-10 as fallback.
#  1. Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.
#  2. Tesla reported strong free cash flow generation of $7.5 billion.
#  3. Tesla's automotive gross margin improved to 19.3% this quarter.
#  4. Tesla's energy storage business grew 40% year-over-year.
#  5. Tesla's Full Self-Driving revenue increased significantly.
#  6. Tesla announced plans to expand Gigafactory production capacity.
#  7. Tesla Cybertruck production ramp begins in 2024 with initial deliveries.
#  8. The Tesla coil was invented by Nikola Tesla in 1891.
#  9. Tesla Model Y became the best-selling vehicle worldwide.
# 10. Tesla stock price reached new highs following earnings announcement.
#
# ================================================================================
# ANALYSIS:
# ✅ Hybrid Search: Mixed relevant and irrelevant results
# ⚠️ Reranking skipped (missing/invalid CO_API_KEY), showing hybrid fallback
# ✅ Notice how top results prioritize query-relevant chunks
#
# ================================================================================
# KEY VIEW (TOP RESULTS):
# ----------------------------------------
# BEFORE (Hybrid Top 5):
#   1. Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.
#   2. Tesla reported strong free cash flow generation of $7.5 billion.
#   3. Tesla's automotive gross margin improved to 19.3% this quarter.
#   4. Tesla's energy storage business grew 40% year-over-year.
#   5. Tesla's Full Self-Driving revenue increased significantly.
#
# AFTER (Step 2 Top 5):
#   1. Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.
#   2. Tesla reported strong free cash flow generation of $7.5 billion.
#   3. Tesla's automotive gross margin improved to 19.3% this quarter.
#   4. Tesla's energy storage business grew 40% year-over-year.
#   5. Tesla's Full Self-Driving revenue increased significantly.

# %% [markdown]
# FINAL RAG: Generate answer with reranked context

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_groq import ChatGroq

print("\n" + "="*80)
print("FINAL: RAG with Reranked Context")
print("-"*40)

# Use top 5 reranked documents for final answer
top_reranked = reranked_docs[:5]

combined_input = f"""Based on the following documents, please answer this question: {query}

Documents:
{chr(10).join([f"- {doc.page_content}" for doc in top_reranked])}

Please provide a clear, helpful answer using only the information from these documents."""

model = ChatGroq(model="llama-3.1-8b-instant", api_key=os.getenv("GROQ_API_KEY"), temperature=0)
messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content=combined_input),
]

result = model.invoke(messages)
print("Generated Response:")
print(result.content)
# Out:
# ================================================================================
# FINAL: RAG with Reranked Context
# ----------------------------------------
# Generated Response:
# Based on the provided documents, here are the key updates on Tesla's financial performance and production:
#
# 1. **Record Quarterly Revenue**: Tesla achieved a record quarterly revenue of $25.2 billion in Q3 2024.
# 2. **Strong Free Cash Flow**: The company generated a strong free cash flow of $7.5 billion.
# 3. **Improved Automotive Gross Margin**: Tesla's automotive gross margin improved to 19.3% in the quarter.
# 4. **Growth in Energy Storage Business**: The energy storage business grew by 40% year-over-year.
# 5. **Significant Growth in Full Self-Driving Revenue**: Tesla's Full Self-Driving revenue saw a significant increase.
#
# These updates indicate a positive financial performance for Tesla in Q3 2024, with significant growth in revenue, free cash flow, and various business segments.
